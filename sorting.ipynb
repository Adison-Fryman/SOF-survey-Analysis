# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/survey_results_public.csv', index_col = 'ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col = 'qname')
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)

#df_sort = df.sort_values(by =['ConvertedCompYearly','YearsCode','CodingActivities'], ascending = False)
# option to have ascending = [False,True,False] if I want to very the asceding/desending of each coulmn
#df_sort[0:15]

#notes
#df.sort_index()
#sort 1 column
#df['Onboarding'].sort_values

# %%
#df.sort_values(by =['ConvertedCompYearly','YearsCode','CodingActivities'],ascending = False, inplace=True) # sorting columns by list

# %%
df.sort_values(by = ['Country','ConvertedCompYearly'],ascending = [True,False]) #sorting by list, but by differnt ascending types
# Out:
#                                 MainBranch  \
# ResponseId
# 38513       I am a developer by profession
# 43640       I am a developer by profession
# 6892        I am a developer by profession
# 43691       I am a developer by profession
# 2449        I am a developer by profession
# ...                                    ...
# 73110                        None of these
# 73158                        None of these
# 73202                        None of these
# 73216                        None of these
# 73244                        None of these
#
#                                                    Employment  \
# ResponseId
# 38513                                     Employed, full-time
# 43640       Employed, full-time;Independent contractor, fr...
# 6892                                      Employed, full-time
# 43691       Employed, full-time;Independent contractor, fr...
# 2449                                      Employed, full-time
# ...

# %%
df[['ConvertedCompYearly','YearsCode','CodingActivities']].head(50) # taking a peak at a secton of the sorted code.

# %%
df['ConvertedCompYearly'].nlargest(10) # looking at the top ten
# Out:
# ResponseId
# 40305    50000000.0
# 202      44790396.0
# 62027    35000000.0
# 70523    32500000.0
# 61044    28853768.0
# 18923    22500000.0
# 62224    22500000.0
# 66496    18000000.0
# 1291     15000000.0
# 24164    15000000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10,'ConvertedCompYearly')  # another way of looking at top ten,
# Out:
#                                 MainBranch  \
# ResponseId
# 40305       I am a developer by profession
# 202         I am a developer by profession
# 62027       I am a developer by profession
# 70523       I am a developer by profession
# 61044       I am a developer by profession
# 18923       I am a developer by profession
# 62224       I am a developer by profession
# 66496       I am a developer by profession
# 1291        I am a developer by profession
# 24164       I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 40305       Independent contractor, freelancer, or self-em...
# 202                                       Employed, full-time
# 62027                                     Employed, full-time
# 70523       Independent contractor, freelancer, or self-em...
# 61044                                     I prefer not to say
# 18923                                     Employed, full-time
# ...

# %%
df.nsmallest(10,'ConvertedCompYearly') # looking at bottom ten
# Out:
#                                                    MainBranch  \
# ResponseId
# 19913       I am not primarily a developer, but I write co...
# 39916                          I am a developer by profession
# 52006                          I am a developer by profession
# 64367       I am not primarily a developer, but I write co...
# 65743                          I am a developer by profession
# 6124                           I am a developer by profession
# 32333                          I am a developer by profession
# 36436                          I am a developer by profession
# 2377                           I am a developer by profession
# 27981                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 19913                                     I prefer not to say
# 39916       Employed, full-time;Independent contractor, fr...
# 52006                                     Employed, full-time
# ...
