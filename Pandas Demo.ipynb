# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')
df.set_index('ResponseId', inplace=True)

# %%
pd.set_option('display.max_columns',85)# applys to both df's schema and results
pd.set_option('display.max_rows',85) # applys to both df's schema and results

# %%
df.head(10)# df.tail() for getting the end of the data
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 9                              I am a developer by profession
# 10                             I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# ...

# %%
df.shape # attribute not a method!
# Out:
# (73268, 78)

# %%
df.info() # method not an attribute
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73268 entries, 1 to 73268
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   MainBranch                      73268 non-null  object
#  1   Employment                      71709 non-null  object
#  2   RemoteWork                      58958 non-null  object
#  3   CodingActivities                58899 non-null  object
#  4   EdLevel                         71571 non-null  object
#  5   LearnCode                       71580 non-null  object
#  6   LearnCodeOnline                 50685 non-null  object
#  7   LearnCodeCoursesCert            29389 non-null  object
#  8   YearsCode                       71331 non-null  object
#  9   YearsCodePro                    51833 non-null  object
#  10  DevType                         61302 non-null  object
#  11  OrgSize                         51039 non-null  object
# ...

# %%
print(df['CodingActivities'].unique())
# Out:
# [nan 'Hobby;Contribute to open-source projects' 'Hobby'
#  'I don’t code outside of work'
#  'Hobby;Contribute to open-source projects;Bootstrapping a business'
#  'Hobby;Contribute to open-source projects;Freelance/contract work'
#  'Hobby;Freelance/contract work' 'Hobby;Bootstrapping a business'
#  'Other (please specify):' 'Contribute to open-source projects'
#  'Hobby;Other (please specify):'
#  'Hobby;Contribute to open-source projects;Bootstrapping a business;Freelance/contract work'
#  'Bootstrapping a business' 'Freelance/contract work'
#  'Hobby;Bootstrapping a business;Freelance/contract work'
#  'Bootstrapping a business;Freelance/contract work'
#  'Hobby;Contribute to open-source projects;Other (please specify):'
#  'Contribute to open-source projects;Freelance/contract work'
#  'Hobby;Freelance/contract work;Other (please specify):'
#  'Contribute to open-source projects;Bootstrapping a business'
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# ...

# %%
schema_df.loc['SOVisitFreq','question'] #.loc[row,column] gives output at that loc in the matrix
# Out:
# 'How frequently would you say you visit Stack Overflow?'

# %%
schema_df.sort_index() ##ascending=False, inplace =True options to include in brackets to change to desending and make permanted change
# Out:
#                          qid  \
# qname
# Accessibility         QID124
# Age                   QID127
# Blockchain            QID305
# BuyNewTool            QID279
# CodingActivities      QID297
# CompFreq               QID52
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Ethnicity             QID126
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Gender                QID122
# ICorPM                QID287
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# Knowledge_5           QID289
# Knowledge_6           QID289
# Knowledge_7           QID289
# Language              QID233
# LearnCode             QID276
# ...

# %%
df.columns # gives lables of all the columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
print(df['CodingActivities']) # this will print any all rows for the called column name and the response id
# Out:
# ResponseId
# 1                                                      NaN
# 2                 Hobby;Contribute to open-source projects
# 3                                                    Hobby
# 4                             I don’t code outside of work
# 5                                                    Hobby
#                                ...
# 73264                              Freelance/contract work
# 73265                                                Hobby
# 73266                        Hobby;School or academic work
# 73267                                                Hobby
# 73268    Hobby;Contribute to open-source projects;Boots...
# Name: CodingActivities, Length: 73268, dtype: object

# %%
df['CodingActivities'].value_counts()# value_counts method counts unique values for a specific collumn, wish i could split this into a bar chart, 1 vote for each answer
# Out:
# Hobby                                                                                                                                        18118
# I don’t code outside of work                                                                                                                  7311
# Hobby;Contribute to open-source projects                                                                                                      6549
# Hobby;Freelance/contract work                                                                                                                 3554
# Hobby;School or academic work                                                                                                                 3016
# Freelance/contract work                                                                                                                       2189
# ...

# %%
#print(df['CodingActivities'].head())
print(df['CodingActivities'].notna().any()) # checking to see that there are non null values- trouble shooting step
# Out:
# True

# %%
print(df['CodingActivities'].notnull().sum()) #then counting those rows, looks like alot
# Out:
# 58899

# %%
# make a copy of the DataFrame
df_copy = df.copy()

# Replace NaN values with an empty string
df_copy['CodingActivities'] = df_copy['CodingActivities'].fillna('')

# Split the values in the 'CodingActivities' column by the delimiter ';'
df_copy['CodingActivities'] = df_copy['CodingActivities'].str.split(';')

# Use the explode() method to create a new row for each value in the resulting lists
df_copy = df_copy.explode('CodingActivities')

# Use the value_counts() method to count the occurrence of each value
counts = df_copy['CodingActivities'].value_counts()

print(counts)
# Out:
# Hobby                                 42922
# Contribute to open-source projects    15378
#                                       14369
# Freelance/contract work               13305
# School or academic work                8561
# Bootstrapping a business               8401
# I don’t code outside of work           7311
# Other (please specify):                2179
# Name: CodingActivities, dtype: int64

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df.loc[0:2,"CodingActivities"] #getting first 3 rows with slice # .loc[rowslice,column] #slice here is inclusive...unlike with pycharm
# Out:
# ResponseId
# 1                                         NaN
# 2    Hobby;Contribute to open-source projects
# Name: CodingActivities, dtype: object

# %%
df.iloc[[0,1,2]] #getting first 3 rows using brackets
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# 2           Hobby;Contribute to open-source projects
# 3                                              Hobby
#
#                                                     EdLevel  \
# ResponseId
# 1                                                       NaN
# ...

# %%
df.loc[0:2,"CodingActivities":'YearsCode'] #slice here is inclusive...unlike with pycharm
# Out:
#                                     CodingActivities EdLevel LearnCode  \
# ResponseId
# 1                                                NaN     NaN       NaN
# 2           Hobby;Contribute to open-source projects     NaN       NaN
#
#            LearnCodeOnline LearnCodeCoursesCert YearsCode
# ResponseId
# 1                      NaN                  NaN       NaN
# 2                      NaN                  NaN       NaN

# %%
#df.set_index('ResponseId')# this sets the index or "id" for the rows.this is not permanent -removed becusae added above when reading in the data

# %%
#df.set_index('ResponseId',inplace = True)# adding the inlpace = True makes the change to DF permanent

# %%
df #print df to notebook for viewing
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df.loc[73267, ['MainBranch','CompTotal'] ] # if the id is supplied it will return all collumns, or specified collumns will be returned
# Out:
# MainBranch    I am a developer by profession
# CompTotal                            58500.0
# Name: 73267, dtype: object

# %%
df.reset_index(inplace = True) # undo the previous index set

# %%
used and what cells have been executed before. Here are some tips that may help you:

Before starting a new notebook, make sure to select the kernel that you want to use. You can do this by going to the Kernel menu and selecting "Change kernel" if needed.

Try to organize your notebook into sections or cells with clear headings. This can help you keep track of what you've done in each section and make it easier to follow your workflow.

Make sure to execute cells in the correct order. You can use the "Run all" option to run all cells in the notebook in order.

Use comments to explain what you are doing in each cell. This can help you and others understand the code more easily.

If you encounter an issue, try restarting the kernel and running the notebook from the beginning. This can sometimes help to resolve issues with kernel conflicts.

I hope these tips help! Don't hesitate to ask if you have any other questions.
# Out:
#   Cell In[25], line 1
#     used and what cells have been executed before. Here are some tips that may help you:
#                   ^
# SyntaxError: invalid syntax

# %%
In the context of Jupyter Notebook, a kernel is a computational engine that executes the code in a notebook document. When you open a notebook, you are connecting to a running kernel, which could be running locally on your computer or remotely on a server.

Each notebook is associated with a single kernel, and the kernel executes the code in the notebook cells. When you run a cell in a Jupyter Notebook, the code in the cell is sent to the kernel for execution. The kernel then sends the results back to the notebook to be displayed.

Different kernels support different programming languages and have different capabilities. For example, the IPython kernel supports Python and interactive computing, while the R kernel supports the R programming language. When you create a new notebook, you can select the kernel you want to use.
