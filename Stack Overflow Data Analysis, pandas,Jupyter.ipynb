# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')
df.set_index('ResponseId', inplace=True)
pd.set_option('display.max_columns',85)# applys to both df's schema and results
pd.set_option('display.max_rows',85) # applys to both df's schema and results
#df.columns
#schema_df.columns

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# ...

# %%
#to-dolist
#1. clean up data/ add more descriptive names to columns, replace NA or empty cells with appropriate data for type.
#2. get into git hub
df['MentalHealth'].head(50)
df_mental = df[(df.MentalHealth != 'None of the above') & (df.MentalHealth !='Prefer not to say')& (df.MentalHealth !='Prefer not to say')] # 
df_mental = df_mental.dropna(subset=['MentalHealth'])
#df_mental['MentalHealth'].head(75)
df_mental['MentalHealth'].value_counts()
#df_mental.shape
# Out:
# I have a concentration and/or memory disorder (e.g., ADHD, etc.)                                                                                                                                                                                                                                                                      2936
# I have an anxiety disorder                                                                                                                                                                                                                                                                                                            2404
# I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.)                                                                                                                                                                                                                                                        1914
# ...

# %%
rename_df = schema_df[66:]
rename_df

rename_dict = {}
#making a dict of just the qname and question so I can turn the question into an ab·breviation.



for index,row in rename_df.iterrows():
    #print(rename_df.loc[index]['question'])
    print(index)
    rename_dict[index] = rename_df.loc[index]['question'] 

rename_dict
# Out:
# {'Knowledge_1': 'I have interactions with people outside of my immediate team.',
#  'Knowledge_2': "Knowledge silos prevent me from getting ideas across the organization (i.e., one individual or team has information that isn't shared with others)",
#  'Knowledge_3': 'I can find up-to-date information within my organization to help me do my job.',
#  'Knowledge_4': 'I am able to quickly find answers to my questions with existing tools and resources.',
#  'Knowledge_5': 'I know which system or resource to use to find information and answers to questions I have.',
#  'Knowledge_6': 'I often find myself answering questions that I’ve already answered before.',
#  'Knowledge_7': 'Waiting on answers to questions often causes interruptions and disrupts my workflow.',
#  'Frequency_1': 'Needing help from people outside of your immediate team?',
#  'Frequency_2': 'Interacting with people outside of your immediate team?',
# ...

# %%
df = df.rename(columns = {'Knowledge_1': 'DevOP interactOutOfMyTeam.',
 'Knowledge_2': "DevOP NegImpactInfoSilos",
 'Knowledge_3': 'up-to-dateIinfo_forjob.',
 'Knowledge_4': 'enough tools resources?',
 'Knowledge_5': 'trained on tools resources?',
 'Knowledge_6': 'often repeat answer to quests',
 'Knowledge_7': 'bottelneck Waiting on answers',
 'Frequency_1': 'Freq: DevOP Need help outside of team?',
 'Frequency_2': 'Freq: DevOP interactOutOfMyTeam',
 'Frequency_3': "Freq:Encounter info silos",
 'TrueFalse_1': 'support new hires?',
 'TrueFalse_2': 'use provided learning reso?',
 'TrueFalse_3': 'Comp give time learn new skills?'})
# Out:
# MainBranch                                73268
# Employment                                71709
# RemoteWork                                58958
# CodingActivities                          58899
# EdLevel                                   71571
# LearnCode                                 71580
# LearnCodeOnline                           50685
# LearnCodeCoursesCert                      29389
# YearsCode                                 71331
# YearsCodePro                              51833
# DevType                                   61302
# OrgSize                                   51039
# PurchaseInfluence                         50969
# BuyNewTool                                67963
# Country                                   71771
# Currency                                  51264
# CompTotal                                 38422
# CompFreq                                  44425
# LanguageHaveWorkedWith                    70975
# LanguageWantToWorkWith                    67027
# ...

# %%
df_count = df.count()
df_count.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 78 entries, MainBranch to ConvertedCompYearly
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 78 non-null     int64
# dtypes: int64(1)
# memory usage: 1.2+ KB

# %%
dict = df_count.to_dict()
dict = sorted(dict.items(),key = lambda x:x[1])
print(dict)
# Out:
# [('VCHostingPersonal use', 0), ('VCHostingProfessional use', 0), ('LearnCodeCoursesCert', 29389), ('OfficeStackAsyncWantToWorkWith', 32072), ('Freq:Encounter info silos', 34515), ('ProfessionalTech', 34906), ('DevOP NegImpactInfoSilos', 34973), ('bottelneck Waiting on answers', 34977), ('often repeat answer to quests', 34991), ('trained on tools resources?', 35014), ('enough tools resources?', 35097), ('up-to-dateIinfo_forjob.', 35133), ('Freq: DevOP interactOutOfMyTeam', 35344), ('Freq: DevOP Need help outside of team?', 35371), ('Onboarding', 35679), ('use provided learning reso?', 35715), ('Comp give time learn new skills?', 35749), ('DevOP interactOutOfMyTeam.', 35804), ('support new hires?', 35819), ('TimeAnswering', 36022), ('TimeSearching', 36198), ('ICorPM', 36283), ('WorkExp', 36769), ('MiscTechWantToWorkWith', 36810), ('ConvertedCompYearly', 38071), ('CompTotal', 38422), ('PlatformWantToWorkWith', 40415), ('CompFreq', 44425), ('MiscTechHaveWorkedWith', 44992), ('WebframeWan
# ...
