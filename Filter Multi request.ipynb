# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv', index_col = 'ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col = 'qname')
pd.set_option('display.max_columns',85)# applys to both df's schema and results
pd.set_option('display.max_rows',85) # applys to both df's schema and results
filt = df['Employment'] == 'Employed, full-time' # filtering column for a specific value, set as a varible,

filt2 = (df['Employment'] =='Employed, full-time') & (df['RemoteWork'] =='Fully remote') # option for filterig, good for looking at several columns and specific values, not so good for wanting multiple answers
filt3 = (df['Employment'] =='Employed, full-time') | (df['RemoteWork'] =='Fully remote') # | this is the "or" opperator
high_salary = (df['CompTotal']>90000)
low_salary = ~(df['CompTotal']>90000) # "~" is the not opperator
countries = ['United States', 'India','United Kingdom',"Germany"]
filt4 = df['Country'].isin(countries) # uses .isin operator
filt5 = df['LanguageHaveWorkedWith'].str.contains('Python',na = False) #using string methods the na= gives a filler
filt6 = (df['Employment'] =='Employed, full-time') & df['Country'].isin(countries) & (df['CompTotal']>80000)

#df.loc[filt,'RemoteWork'] #second option filters data out but lets you grab other collomns...prints
#df.loc[filt2] # use .loc[filter variable] to print out results...prints
#df.loc[filt3] ...prints
#df.loc[high_salary,['Country','LanguageHaveWorkedWith','CompTotal' ]].head() # finding the high salary entries, and returning specific columns with it
#df.loc[low_salary].head()...prints
#df[filt4].head()...prints
#df.loc[filt5, "LanguageHaveWorkedWith"]
#df.loc[filt6]

# %%
df_sorted = df[filt6].sort_values(by='CompTotal', ascending=False)

# %%
df_sorted
# Out:
#                                 MainBranch           Employment  \
# ResponseId
# 64898       I am a developer by profession  Employed, full-time
# 12132       I am a developer by profession  Employed, full-time
# 25938       I am a developer by profession  Employed, full-time
# 9796        I am a developer by profession  Employed, full-time
# 57354       I am a developer by profession  Employed, full-time
# ...                                    ...                  ...
# 2258        I am a developer by profession  Employed, full-time
# 68144       I am a developer by profession  Employed, full-time
# 49265       I am a developer by profession  Employed, full-time
# 64113       I am a developer by profession  Employed, full-time
# 6737        I am a developer by profession  Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 64898                               Fully remote
# 12132       Hybrid (some remote, some in-person)
# ...

# %%
top_salaries = df_sorted['CompTotal'].nlargest(2)
bot_salaries = df_sorted['CompTotal'].nsmallest(2)
display(top_salaries)
display(bot_salaries)
#when you're running multiple lines of code in the same cell, only the last line's output is displayed in the notebook. If you want to see the output of each line, you can either run each line separately in a new cell or use the display() function to explicitly display the output of each line.
# Out:
# ResponseId
# 64898    510000000.0
# 12132     25000000.0
# Name: CompTotal, dtype: float64
# ResponseId
# 6737     80400.0
# 64113    80500.0
# Name: CompTotal, dtype: float64
