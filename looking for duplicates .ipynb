# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')
df.set_index('ResponseId', inplace=True)
pd.set_option('display.max_columns',85)# applys to both df's schema and results
pd.set_option('display.max_rows',85) # applys to both df's schema and results
#df.columns
#schema_df.columns

# %%
display(df.shape)
duplicate_rows = df.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
duplicate_rows = df[df.duplicated()]
display(duplicate_rows.head(75))
# Out:
# (73268, 78)
# Number of duplicate rows: 1496
#                MainBranch Employment RemoteWork CodingActivities EdLevel  \
# ResponseId
# 31          None of these        NaN        NaN              NaN     NaN
# 87          None of these        NaN        NaN              NaN     NaN
# 147         None of these        NaN        NaN              NaN     NaN
# 191         None of these        NaN        NaN              NaN     NaN
# 231         None of these        NaN        NaN              NaN     NaN
# 543         None of these        NaN        NaN              NaN     NaN
# 706         None of these        NaN        NaN              NaN     NaN
# 1118        None of these        NaN        NaN              NaN     NaN
# 1143        None of these        NaN        NaN              NaN     NaN
# 1149        None of these        NaN        NaN              NaN     NaN
# 1205        None of these        NaN        NaN              NaN     NaN
# ...

# %%
#print(type(df_45))
# removing unwated rows
filt = df['Country'] == 'India'
test= df[filt].sort_values(by = 'ConvertedCompYearly' )
test
#display(test.shape)
#duplicate_rows = test.duplicated()
#print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
#                                                    MainBranch  \
# ResponseId
# 39916                          I am a developer by profession
# 65743                          I am a developer by profession
# 58971       I am not primarily a developer, but I write co...
# 4239                           I am a developer by profession
# 36976                          I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 39916       Employed, full-time;Independent contractor, fr...
# 65743                                     Employed, full-time
# ...

# %%
display(test.shape)
duplicate_rows = test.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())

# %%
0(639, 78)
